# %%
import pandas as pd
from sqlalchemy import create_engine, text
from google.colab import files

# 1. Connect to your Neon Database using your credentials
neon_url = "postgresql://neondb_owner:npg_XGQ2u1jKdTHz@ep-lively-hill-aswbnogx-pooler.c-4.eu-central-1.aws.neon.tech:5432/neondb"
engine = create_engine(neon_url)

# 2. See what tables your friend actually put in Neon
with engine.connect() as conn:
    result = conn.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'"))
    print("Tables found inside Neon:")
    for row in result:
        print(f" -> {row[0]}")

# 3. Extract the data (NOTE: If the printout above shows different names, update the SQL below)
print("\nExtracting data...")
df_drivers = pd.read_sql("SELECT * FROM drivers", engine)
df_races = pd.read_sql("SELECT * FROM races", engine)

# 4. Save to CSV and download to your computer
df_drivers.to_csv("neon_drivers.csv", index=False)
df_races.to_csv("neon_races.csv", index=False)

files.download("neon_drivers.csv")
files.download("neon_races.csv")
print("Extraction Complete! Files downloaded.")
# Out:
# Tables found inside Neon:
#  -> drivers
#  -> races
#
# Extracting data...
# Extraction Complete! Files downloaded.
